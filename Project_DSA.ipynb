# %% [markdown]
# <a href="https://colab.research.google.com/github/Laiba-Akhtar/Data_Science_and_Analytics_20sw057_task/blob/main/Project_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

# %% [markdown]
# TITLE: ADDS ANALYSIS
# PROJECT DESCRIPTION: The project purpose is to analyse the advertisement dataset features to analyse the Click on Ads for marketing and brand analysis
# GROUP MEMBERS:
# Laiba Akhtar 20sw057
# Isha Bhutto 20sw035
# Nayab 20sw101

# %% [markdown]
# Goal 8: Decent Work and Economic Growth: Clicking on advertisements can contribute to economic growth by driving traffic to businesses, potentially leading to job creation and business expansion.
#
# Goal 9: Industry, Innovation, and Infrastructure: Online advertising is closely related to technology, innovation, and digital infrastructure. It supports the growth of digital industries and the development of new technologies.

# %% [markdown]
# The data set chosed is of advertisements from kaggle

# %%
data = pd.read_csv("/content/advertising (1).csv")

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %%
data.tail()
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 995                     72.97   30     71384.57                208.58
# 996                     51.30   45     67782.17                134.42
# 997                     51.63   51     42415.72                120.37
# 998                     55.55   19     41920.79                187.95
# 999                     45.01   26     29875.80                178.35
#
#                             Ad Topic Line           City  Male  \
# 995         Fundamental modular algorithm      Duffystad     1
# 996       Grass-roots cohesive monitoring    New Darlene     1
# 997          Expanded intangible solution  South Jessica     1
# 998  Proactive bandwidth-monitored policy    West Steven     0
# 999       Virtual 5thgeneration emulation    Ronniemouth     0
#
#                     Country            Timestamp  Clicked on Ad
# 995                 Lebanon  2016-02-11 21:49:00              1
# ...

# %% [markdown]
# Checking if data set have null values

# %%
data.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Ad Topic Line               0
# City                        0
# Male                        0
# Country                     0
# Timestamp                   0
# Clicked on Ad               0
# dtype: int64

# %% [markdown]
# Three Business Questions
#
# Customer Behavior and Customer Demographics
# What are the customer behaviours according to the given attributes?
# What demographics such as age,gender and timestamp play role?
# Add Effectiveness
# Was the add more effective to clicked?

# %%
print(data.columns)
# Out:
# Index(['Daily Time Spent on Site', 'Age', 'Area Income',
#        'Daily Internet Usage', 'Ad Topic Line', 'City', 'Male', 'Country',
#        'Timestamp', 'Clicked on Ad'],
#       dtype='object')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB
# None

# %%
print(data.describe())
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# DATA CLEANING To remove irrelevant data

# %%
data.drop('Country',inplace=True,axis=1)
data.drop('City',inplace=True,axis=1)
data.drop('Area Income',inplace=True,axis=1)

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Daily Internet Usage  \
# 0                     68.95   35                256.09
# 1                     80.23   31                193.77
# 2                     69.47   26                236.50
# 3                     74.15   29                245.89
# 4                     68.37   35                225.58
#
#                            Ad Topic Line  Male            Timestamp  \
# 0     Cloned 5thgeneration orchestration     0  2016-03-27 00:53:11
# 1     Monitored national standardization     1  2016-04-04 01:39:02
# 2       Organic bottom-line service-desk     0  2016-03-13 20:35:42
# 3  Triple-buffered reciprocal time-frame     1  2016-01-10 02:31:19
# 4          Robust logistical utilization     0  2016-06-03 03:36:18
#
#    Clicked on Ad
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Daily Internet Usage      1000 non-null   float64
#  3   Ad Topic Line             1000 non-null   object
#  4   Male                      1000 non-null   int64
#  5   Timestamp                 1000 non-null   object
#  6   Clicked on Ad             1000 non-null   int64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 54.8+ KB

# %% [markdown]
# Total Clicks and no clicks and Average Time Spent on Site for ads to get daily time spent

# %%
import pandas as pd


# Separate data for customers who clicked on ads and those who didn't
clicked_on_ads = data[data['Clicked on Ad'] == 1]
did_not_click_on_ads = data[data['Clicked on Ad'] == 0]

#total_clicks=data['Clicked on Ad']
total_clicks =  data[data['Clicked on Ad'] == 1]['Clicked on Ad'].count()
total_no_clicks =  data[data['Clicked on Ad'] == 0]['Clicked on Ad'].count()
print("Total click on ads",total_clicks)
print("Total no clicks on ads",total_no_clicks)


# Calculate average time spent for each group
avg_time_clicked = clicked_on_ads['Daily Time Spent on Site'].mean()
avg_time_not_clicked = did_not_click_on_ads['Daily Time Spent on Site'].mean()

# Print the results
print(f'Average time spent for customers who clicked on ads: {avg_time_clicked} minutes')
print(f'Average time spent for customers who did not click on ads: {avg_time_not_clicked} minutes')
# Out:
# Total click on ads 500
# Total no clicks on ads 500
# Average time spent for customers who clicked on ads: 53.14578 minutes
# Average time spent for customers who did not click on ads: 76.85462 minutes

# %% [markdown]
# Daily Internet Usage,Clicks on add and Daily Time Spent on Site relationship

# %%
correlation_matrix = data[['Daily Internet Usage', 'Clicked on Ad', 'Daily Time Spent on Site']].corr()

# Create a heatmap
plt.figure(figsize=(8, 6))
sb.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# here it can be shown that the average time spent of users who click on add is more than those who did not click on ads

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['Daily Time Spent on Site'], data['Clicked on Ad'], alpha=0.5)
plt.title('Scatter Plot of Daily Time Spent on Site  vs Clicked Ad')
plt.xlabel('Daily Time Spent on Site ')
plt.ylabel('Clicked Ad (1 for Yes, 0 for No)')
plt.show()

# %%
# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['Daily Internet Usage'], data['Clicked on Ad'], alpha=0.5)
plt.title('Scatter Plot: Daily Internet Usage vs. Clicked Ad')
plt.xlabel('Daily Internet Usage')
plt.ylabel('Clicked Ad (1 for Click, 0 for No Click)')
plt.show()

# %% [markdown]
# The geenral relationship of age and its frequency

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Age Distribution
ax1.hist(data['Age'], bins=20, color='skyblue', edgecolor='black')
ax1.set_title('Age Distribution')
ax1.set_xlabel('Age')
ax1.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# Age wise  frequency of clicking adds

# %%
age_click_frequency = data.groupby('Age')['Clicked on Ad'].sum().reset_index()

# Create a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(age_click_frequency['Age'], age_click_frequency['Clicked on Ad'], color='blue', alpha=0.5)
plt.title('Age vs. Frequency of Clicking on Ads')
plt.xlabel('Age')
plt.ylabel('Frequency of Clicking on Ads')
plt.show()

# %% [markdown]
# Here it can be seen that the majority of the person who click adds are of 30 +

# %%
plt.figure(figsize=(10, 6))

# Plot Age Distribution for Clicked Ads = 1
plt.hist(data[data['Clicked on Ad'] == 1]['Age'], bins=20, color='green', alpha=0.6, label='Clicked Ads = 1', edgecolor='black')

# Plot Age Distribution for Clicked Ads = 0
plt.hist(data[data['Clicked on Ad'] == 0]['Age'], bins=20, color='orange', alpha=0.6, label='Clicked Ads = 0', edgecolor='black')

plt.title('Age Distribution by Clicked Ads')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot 1: Age Distribution for Clicked Ads = 1
ax1.hist(data[data['Clicked on Ad'] == 1]['Age'], bins=20, color='green', edgecolor='black')
ax1.set_title('Age Distribution for Clicked Ads = 1')
ax1.set_xlabel('Age')
ax1.set_ylabel('Frequency')

# Plot 2: Age Distribution for Clicked Ads = 0
ax2.hist(data[data['Clicked on Ad'] == 0]['Age'], bins=20, color='orange', edgecolor='black')
ax2.set_title('Age Distribution for Clicked Ads = 0')
ax2.set_xlabel('Age')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Majority of people who click do not click on add are younger than 35

# %% [markdown]
# Here we get to know about the relationship between gender and clicking on add where we found most of the people who clicked ads are females

# %%
grouped_data = data.groupby(['Clicked on Ad', 'Male']).size().unstack()
grouped_data.plot(kind='bar', figsize=(10, 6), color=['skyblue', 'salmon'], edgecolor='black')

plt.title('Relationship between Clicking on Ads and Gender')
plt.xlabel('Clicked Ad (0 or 1)')
plt.ylabel('Frequency')
plt.xticks(ticks=[0, 1], labels=['Did Not Click', 'Clicked'], rotation=0)
plt.legend(['Female', 'Male'])
plt.show()

# %%
# Group the data by Headline and count the frequency of clicks
headline_click_frequency = data.groupby('Ad Topic Line')['Clicked on Ad'].sum().reset_index()

# Sort the data by frequency of clicks in descending order
headline_click_frequency = headline_click_frequency.sort_values(by='Clicked on Ad', ascending=False)

# Create a bar plot
plt.figure(figsize=(12, 6))
plt.bar(headline_click_frequency['Ad Topic Line'], headline_click_frequency['Clicked on Ad'], color='teal')
plt.title('Click Frequency by Ad Headline')
plt.xlabel('Ad Headline')
plt.ylabel('Frequency of Clicks')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
# Filter data for Clicked_Ad == 1
clicked_ads_data = data[data['Clicked on Ad'] == 1]

# Get unique ad headlines and their frequencies
ad_headline_frequencies = clicked_ads_data['Ad Topic Line'].value_counts()

# Sort ad headlines by frequency in descending order
sorted_ad_headlines = ad_headline_frequencies.sort_values(ascending=False)

# Print ad headlines in descending order
for ad_headline, frequency in sorted_ad_headlines.head(10).items():
    print(f'Ad Headline: {ad_headline}, Frequency: {frequency}')
# Out:
# Ad Headline: Reactive local challenge, Frequency: 1
# Ad Headline: Synchronized dedicated service-desk, Frequency: 1
# Ad Headline: Centralized content-based focus group, Frequency: 1
# Ad Headline: Grass-roots coherent extranet, Frequency: 1
# Ad Headline: Persistent demand-driven interface, Frequency: 1
# Ad Headline: Customizable multi-tasking website, Frequency: 1
# Ad Headline: Grass-roots solution-oriented conglomeration, Frequency: 1
# Ad Headline: Advanced 24/7 productivity, Frequency: 1
# Ad Headline: Mandatory disintermediate utilization, Frequency: 1
# Ad Headline: Exclusive neutral parallelism, Frequency: 1

# %%
plt.figure(figsize=(10, 6))
sb.scatterplot(x='Age', y='Daily Time Spent on Site', hue='Clicked on Ad', data=data)
plt.title('Age vs. Daily Time Spent on Site by Clicked on Ad')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Convert 'Timestamp' to datetime format
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# Extract hour and day of week from 'Timestamp'
data['Hour'] = data['Timestamp'].dt.hour
data['DayOfWeek'] = data['Timestamp'].dt.day_name()

# Hourly Trends
hourly_data = data.groupby('Hour').mean()
daily_data = data.groupby('DayOfWeek').mean()
plt.figure(figsize=(12, 6))
plt.plot(hourly_data['Daily Time Spent on Site'], label='Daily Time Spent on Site')
plt.plot(daily_data['Clicked on Ad'], label='Clicked on Ad')
plt.plot(hourly_data['Daily Internet Usage'], label='Daily Internet Usage')
plt.title('Hourly Trends')
plt.xlabel('Hour')
plt.ylabel('Metrics')
plt.legend()
plt.show()

# Daily Trends
daily_data = data.groupby('DayOfWeek').mean()

plt.figure(figsize=(12, 6))
plt.plot(daily_data['Daily Time Spent on Site'], label='Daily Time Spent on Site')
plt.plot(daily_data['Clicked on Ad'], label='Clicked on Ad')
plt.plot(daily_data['Daily Internet Usage'], label='Daily Internet Usage')
plt.title('Daily Trends')
plt.xlabel('Day of Week')
plt.ylabel('Metrics')
plt.legend()
plt.show()
# Out:
# <ipython-input-26-1f46726d142b>:13: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   hourly_data = data.groupby('Hour').mean()
# <ipython-input-26-1f46726d142b>:14: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_data = data.groupby('DayOfWeek').mean()
# <ipython-input-26-1f46726d142b>:26: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   daily_data = data.groupby('DayOfWeek').mean()

# %% [markdown]
# Normalizing timestamp for modeling

# %%
data['Timestamp'] = pd.to_datetime(data['Timestamp'])

# Extract features from 'Timestamp'
data['Hour'] = data['Timestamp'].dt.hour
data['Minute'] = data['Timestamp'].dt.minute
data['DayOfWeek'] = data['Timestamp'].dt.dayofweek  # Monday=0, Sunday=6
data['Day'] = data['Timestamp'].dt.day
data['Month'] = data['Timestamp'].dt.month
data['Year'] = data['Timestamp'].dt.year

# Drop the original 'Timestamp' column if it's no longer needed
data = data.drop(columns=['Timestamp'])

# %%
y=data['Clicked on Ad']

# %%
data.drop('Clicked on Ad',axis=1,inplace=True)

# %%
data.drop('Ad Topic Line',axis=1,inplace=True)

# %% [markdown]
# Splitting the data into training and testing set

# %%
from sklearn.model_selection import train_test_split



X=data
# Set the test_size parameter to specify the proportion of data to allocate for testing
# Here, 0.2 means 20% of the data will be used for testing, and 80% for training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Print the shapes to verify the split
print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
# Out:
# Shape of X_train: (700, 10)
# Shape of X_test: (300, 10)

# %% [markdown]
# After splitting applying linear regression model as we are having a binary classification
# Either user will play ad or not

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
model = LogisticRegression()
model.fit(X_train, y_train)


# Predict the labels on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{classification_rep}');
# Out:
# Accuracy: 0.9466666666666667
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.97      0.95       146
#            1       0.97      0.93      0.95       154
#
#     accuracy                           0.95       300
#    macro avg       0.95      0.95      0.95       300
# weighted avg       0.95      0.95      0.95       300
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
model.score(X_test,y_test)
# Out:
# 0.9466666666666667

# %% [markdown]
# Visualize model

# %%
data.hist(figsize=(10,11))
plt.show()

# %%
data.head()
# Out:
#    Daily Time Spent on Site  Age  Daily Internet Usage  Male  Hour  DayOfWeek  \
# 0                     68.95   35                256.09     0     0          6
# 1                     80.23   31                193.77     1     1          0
# 2                     69.47   26                236.50     0    20          6
# 3                     74.15   29                245.89     1     2          6
# 4                     68.37   35                225.58     0     3          4
#
#    Minute  Day  Month  Year
# 0      53   27      3  2016
# 1      39    4      4  2016
# 2      35   13      3  2016
# 3      31   10      1  2016
# 4      36    3      6  2016

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Daily Internet Usage      1000 non-null   float64
#  3   Male                      1000 non-null   int64
#  4   Hour                      1000 non-null   int64
#  5   DayOfWeek                 1000 non-null   int64
#  6   Minute                    1000 non-null   int64
#  7   Day                       1000 non-null   int64
#  8   Month                     1000 non-null   int64
#  9   Year                      1000 non-null   int64
# dtypes: float64(2), int64(8)
# memory usage: 78.2 KB

# %% [markdown]
# Applying confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Assuming y_true and y_pred are your true and predicted labels
cm = confusion_matrix(y_test, y_pred)

# Create a heatmap for the confusion matrix
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Get the predicted probabilities
y_probs = model.predict_proba(X_test)[:, 1]

# Calculate the ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_probs)

# Plot the ROC curve
plt.plot(fpr, tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.show()

# %% [markdown]
# Here you can see ROC curve produce good results
